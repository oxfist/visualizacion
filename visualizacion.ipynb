# %% [markdown]
# ## Dependencias

# %%
# %pip install pandas nltk matplotlib firebase-admin python-dotenv
# Out:
# Requirement already satisfied: pandas in /Users/oxfist/.pyenv/versions/3.12.2/lib/python3.12/site-packages (2.2.2)
# Requirement already satisfied: nltk in /Users/oxfist/.pyenv/versions/3.12.2/lib/python3.12/site-packages (3.8.1)
# Requirement already satisfied: matplotlib in /Users/oxfist/.pyenv/versions/3.12.2/lib/python3.12/site-packages (3.8.4)
# Requirement already satisfied: firebase-admin in /Users/oxfist/.pyenv/versions/3.12.2/lib/python3.12/site-packages (6.5.0)
# Requirement already satisfied: python-dotenv in /Users/oxfist/.pyenv/versions/3.12.2/lib/python3.12/site-packages (1.0.1)
# Requirement already satisfied: numpy>=1.26.0 in /Users/oxfist/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/oxfist/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/oxfist/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/oxfist/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: click in /Users/oxfist/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /Users/oxfist/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/oxfist/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from nltk) (2024.5.15)
# Requirement already satisfied: tqdm in /Users/oxfist/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from nltk) (4.66.4)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/oxfist/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /Users/oxfist/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/oxfist/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/oxfist/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/oxfist/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=8 in /Users/oxfist/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/oxfist/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: cachecontrol>=0.12.6 in /Users/oxfist/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from firebase-admin) (0.14.0)
# Requirement already satisfied: google-api-python-client>=1.7.8 in /Users/oxfist/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from firebase-admin) (2.132.0)
# Requirement already satisfied: google-cloud-storage>=1.37.1 in /Users/oxfist/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from firebase-admin) (2.16.0)
# Requirement already satisfied: pyjwt>=2.5.0 in /Users/oxfist/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from pyjwt[crypto]>=2.5.0->firebase-admin) (2.8.0)
# Requirement already satisfied: google-api-core<3.0.0dev,>=1.22.1 in /Users/oxfist/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (2.19.0)
# Requirement already satisfied: google-cloud-firestore>=2.9.1 in /Users/oxfist/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from firebase-admin) (2.16.0)
# Requirement already satisfied: requests>=2.16.0 in /Users/oxfist/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from cachecontrol>=0.12.6->firebase-admin) (2.32.3)
# Requirement already satisfied: msgpack<2.0.0,>=0.5.2 in /Users/oxfist/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from cachecontrol>=0.12.6->firebase-admin) (1.0.8)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /Users/oxfist/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (1.63.1)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in /Users/oxfist/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (4.25.3)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /Users/oxfist/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (1.23.0)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in /Users/oxfist/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (2.30.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /Users/oxfist/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (1.64.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /Users/oxfist/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (1.62.2)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in /Users/oxfist/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from google-api-python-client>=1.7.8->firebase-admin) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /Users/oxfist/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from google-api-python-client>=1.7.8->firebase-admin) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /Users/oxfist/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from google-api-python-client>=1.7.8->firebase-admin) (4.1.1)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.4.1 in /Users/oxfist/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from google-cloud-firestore>=2.9.1->firebase-admin) (2.4.1)
# Requirement already satisfied: google-resumable-media>=2.6.0 in /Users/oxfist/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from google-cloud-storage>=1.37.1->firebase-admin) (2.7.0)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /Users/oxfist/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from google-cloud-storage>=1.37.1->firebase-admin) (1.5.0)
# Requirement already satisfied: cryptography>=3.4.0 in /Users/oxfist/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from pyjwt[crypto]>=2.5.0->firebase-admin) (42.0.8)
# Requirement already satisfied: six>=1.5 in /Users/oxfist/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: cffi>=1.12 in /Users/oxfist/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.5.0->firebase-admin) (1.16.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/oxfist/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/oxfist/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/oxfist/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (4.9)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/oxfist/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from requests>=2.16.0->cachecontrol>=0.12.6->firebase-admin) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/oxfist/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from requests>=2.16.0->cachecontrol>=0.12.6->firebase-admin) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/oxfist/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from requests>=2.16.0->cachecontrol>=0.12.6->firebase-admin) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/oxfist/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from requests>=2.16.0->cachecontrol>=0.12.6->firebase-admin) (2024.6.2)
# Requirement already satisfied: pycparser in /Users/oxfist/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from cffi>=1.12->cryptography>=3.4.0->pyjwt[crypto]>=2.5.0->firebase-admin) (2.22)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /Users/oxfist/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (0.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Pipeline
#
# ### 1. Preprocesamiento
# 1. Bajar todas las votaciones desde Firebase y dejarla en una lista
# 2. Construir un `pandas.DataFrame` con los datos de Firebase
# 3. Agregar una dimensión al data frame con vector de _stemmed tokens_
# 4. Quitar subconjunto de palabras a ignorar ('señor', 'inciso', etc.)
#
# ### 2. Análisis Exploratorio
# 1. Filtrar por años de interés
# 2. Visualizar distribuciones de atributos de interés
# 3. Hacer primeras preguntas a poder responder con los datos

# %% [markdown]
# ### Conexión Firebase

# %%
from dotenv import dotenv_values, find_dotenv

import firebase_admin # type: ignore
from firebase_admin import credentials, firestore

async def firebase_connection():
    config = dotenv_values(find_dotenv())

    firebase_credentials_file_path = config["FIREBASE_CREDENTIALS"]
    cred = credentials.Certificate(firebase_credentials_file_path)

    if not firebase_admin._apps:
        firebase_admin.initialize_app(cred)

    db = firestore.client()

    return db

db = await firebase_connection()
db

# %% [markdown]
# ### Traer Votaciones de Firebase

# %%
import pandas as pd

votaciones_docs = db.collection("votaciones").stream()
votaciones = list(map(lambda doc: doc.to_dict(), votaciones_docs))

votaciones_df = pd.DataFrame(votaciones)

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
from nltk.tokenize import RegexpTokenizer, WordPunctTokenizer

nltk.download("stopwords")

stemmer = SnowballStemmer("spanish")
stop_words = set(stopwords.words("spanish"))
additional_stop_words = set([
  'ley',
  'señor',
  'proyect',
  'boletin',
  'aprob',
  'tramit',
  'establec',
  'nº',
  'constitucional',
  'segund',
  'indic',
  'comision',
  'modif',
  'articul',
  'republ',
  'inform',
  'acuerd',
  'general',
  'votacion',
  'president',
  'part',
  'senador',
  'prim',
  'nacional',
  'honor',
  'solicit',
  'particul',
  'public'
])

def filter_useful_tokens(token):
  return len(token) > 1 and token not in stop_words and token not in additional_stop_words and not token.isdigit()

def tokenize(materia):
  numero_boletin = RegexpTokenizer(r"[Bb]olet[íi]n.*\d+").tokenize(materia)

  if len(numero_boletin) > 0:
    numero_boletin = "".join(re.findall(r"[0-9-]+", numero_boletin[0]))
  else:
    numero_boletin = ""

  tokenized_materia = RegexpTokenizer(r"\w+").tokenize(materia)
  tokenized_materia = WordPunctTokenizer().tokenize(" ".join(tokenized_materia))
  tokenized_materia = [token.lower() for token in tokenized_materia]
  tokenized_materia.append(numero_boletin)
  tokenized_materia = list(filter(filter_useful_tokens, tokenized_materia))

  return tokenized_materia

def stem(tokenized_materia):
  stemmed_materia = [
      stemmer.stem(token) for token in tokenized_materia if token.lower() not in stop_words
  ]
  stemmed_materia = list(filter(filter_useful_tokens, stemmed_materia))
  return stemmed_materia

votaciones_df['tokenized_materia'] = votaciones_df['materia'].apply(tokenize)
votaciones_df['stemmed_materia'] = votaciones_df['tokenized_materia'].apply(stem)
votaciones_df
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/oxfist/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#              fecha_str resultado boletin_numero    id  legislatura_id  \
# 0     12/03/2013 19:55                  6190-19  5000             484
# 1     13/03/2013 16:33                  7818-14  5001             484
# 2     13/03/2013 17:11                  6967-06  5002             484
# 3     19/03/2013 13:07                  6190-19  5003             484
# 4     19/03/2013 13:11                  6190-19  5004             484
# ...                ...       ...            ...   ...             ...
# 4579  05/03/2024 20:21                           9661             503
# 4580  06/03/2024 15:38                 2.524-12  9662             503
# 4581  06/03/2024 16:23                 16576-08  9663             503
# 4582  06/03/2024 17:18                 16408-05  9664             503
# 4583  06/03/2024 17:41                 16302-04  9665             503
#
#                                                     url  sesion_numero  \
# 0     https://www.senado.cl/appsenado/index.php?mo=s...              1
# 1     https://www.senado.cl/appsenado/index.php?mo=s...              2
# 2     https://www.senado.cl/appsenado/index.php?mo=s...              2
# 3     https://www.senado.cl/appsenado/index.php?mo=s...              3
# 4     https://www.senado.cl/appsenado/index.php?mo=s...              3
# ...                                                 ...            ...
# 4579  https://www.senado.cl/appsenado/index.php?mo=s...            101
# 4580  https://www.senado.cl/appsenado/index.php?mo=s...            103
# 4581  https://www.senado.cl/appsenado/index.php?mo=s...            103
# 4582  https://www.senado.cl/appsenado/index.php?mo=s...            103
# 4583  https://www.senado.cl/appsenado/index.php?mo=s...            103
#
#      tramite_constitucional  \
# 0
# 1
# 2
# 3
# 4
# ...                     ...
# 4579
# 4580
# 4581
# 4582
# 4583
#
#                                                 detalle  sesion_id  ...  \
# 0     {'NO': ['Alvear V., Soledad', 'Cantero O., Car...       6799  ...
# 1     {'NO': [], 'SI': ['Allende B., Isabel', 'Bianc...       6801  ...
# 2     {'NO': [], 'SI': ['Allende B., Isabel', 'Alvea...       6801  ...
# 3     {'NO': ['Allende B., Isabel', 'Gómez U., José ...       6803  ...
# 4     {'NO': [], 'SI': ['Alvear V., Soledad', 'Bianc...       6803  ...
# ...                                                 ...        ...  ...
# 4579  {'NO': ['Coloma C., Juan Antonio', 'Ebensperge...       9625  ...
# 4580  {'NO': [], 'SI': ['Allende B., Isabel', 'Arave...       9627  ...
# 4581  {'NO': [], 'SI': ['Aravena A., Carmen Gloria',...       9627  ...
# 4582  {'NO': [], 'SI': ['Allende B., Isabel', 'Arave...       9627  ...
# 4583  {'NO': ['Kuschel S., Carlos Ignacio'], 'SI': [...       9627  ...
#
#       articulo  camara tipo votos_no                quorum  votos_si  \
# 0               SENADO            22  Cuatro séptimos Q.C.         5
# 1               SENADO             0  Cuatro séptimos Q.C.        25
# 2               SENADO             0        Mayoría simple        29
# 3               SENADO             8  Cuatro séptimos Q.C.        26
# 4               SENADO             0  Cuatro séptimos Q.C.        27
# ...        ...     ...  ...      ...                   ...       ...
# 4579            SENADO             3                  Q.C.        36
# 4580            SENADO             0        Mayoría simple        24
# 4581            SENADO             0        Mayoría simple        32
# 4582            SENADO             0                  Q.C.        37
# 4583            SENADO             1        Mayoría simple        27
#
#                                                 materia  votos_abs  \
# 0     Votaciòn de la indicación número 200 bis.-, re...          1
# 1     Votación que aprueba en particular el proyecto...          0
# 2     Votación que aprueba en general y en particula...          0
# 3     Aprobación del inciso primero del artículo 15 ...          0
# 4     Aprobación del incisos segundo y tercero del a...          1
# ...                                                 ...        ...
# 4579  Enmiendas por mayorías, entre ellas, normas de...          1
# 4580  \n Proyecto de acuerdo de los Honorables  Sena...          0
# 4581  Proyecto de ley, iniciado en Mensaje de Su Exc...          1
# 4582  Proyecto de ley, en primer trámite constitucio...          0
# 4583  Proyecto de ley, en segundo trámite constituci...          0
#
#                                       tokenized_materia  \
# 0         [votaciòn, indicación, número, bis, renovada]
# 1     [votación, aprueba, particular, proyecto, renu...
# 2     [votación, aprueba, particularel, proyecto, se...
# 3     [aprobación, inciso, primero, artículo, conten...
# 4     [aprobación, incisos, segundo, tercero, artícu...
# ...                                                 ...
# 4579   [enmiendas, mayorías, normas, quórum, aprobadas]
# 4580  [proyecto, acuerdo, honorables, senadores, señ...
# 4581  [proyecto, iniciado, mensaje, excelencia, pres...
# 4582  [proyecto, primer, trámite, modifica, diversos...
# 4583  [proyecto, segundo, trámite, modifica, univers...
#
#                                         stemmed_materia
# 0                         [votaciòn, numer, bis, renov]
# 1     [aprueb, renuev, proced, regulariz, ampliacion...
# 2     [aprueb, particularel, decl, feri, dia, juni, ...
# 3     [incis, primer, conten, pas, ser, 1º, permit, ...
# 4     [incis, tercer, conten, pas, ser, 1º, permit, ...
# ...                                                 ...
# 4579                     [enmiend, mayor, norm, quorum]
# 4580  [nuñez, araven, carvajal, gatic, pascual, prov...
# 4581  [inici, mensaj, excelent, divers, cuerp, legal...
# 4582  [divers, cuerp, legal, objet, adopt, med, comb...
# 4583  [univers, estatal, cre, univers, biobi, autori...
#
# [4584 rows x 22 columns]

# %%
votaciones_df['fecha'] = pd.to_datetime(votaciones_df['fecha_str'], format='%d/%m/%Y %H:%M').dt.date

# %%
start_date = pd.to_datetime('11/03/2018 00:00:00', format='%d/%m/%Y %H:%M:%S').date()
end_date = pd.to_datetime('10/03/2024 23:59:59', format='%d/%m/%Y %H:%M:%S').date()

votaciones_df = votaciones_df[(votaciones_df['fecha'] >= start_date) & (votaciones_df['fecha'] <= end_date)]
votaciones_df
# Out:
#              fecha_str resultado boletin_numero    id  legislatura_id  \
# 2066  13/03/2018 16:49                 11465-22  7134             489
# 2067  14/03/2018 16:22                 10217-15  7135             489
# 2068  14/03/2018 16:52                 11269-05  7136             489
# 2069  14/03/2018 17:12                 10456-15  7137             489
# 2070  14/03/2018 17:19                 10456-15  7138             489
# ...                ...       ...            ...   ...             ...
# 4579  05/03/2024 20:21                           9661             503
# 4580  06/03/2024 15:38                 2.524-12  9662             503
# 4581  06/03/2024 16:23                 16576-08  9663             503
# 4582  06/03/2024 17:18                 16408-05  9664             503
# 4583  06/03/2024 17:41                 16302-04  9665             503
#
#                                                     url  sesion_numero  \
# 2066  https://www.senado.cl/appsenado/index.php?mo=s...              1
# 2067  https://www.senado.cl/appsenado/index.php?mo=s...              2
# 2068  https://www.senado.cl/appsenado/index.php?mo=s...              2
# 2069  https://www.senado.cl/appsenado/index.php?mo=s...              2
# 2070  https://www.senado.cl/appsenado/index.php?mo=s...              2
# ...                                                 ...            ...
# 4579  https://www.senado.cl/appsenado/index.php?mo=s...            101
# 4580  https://www.senado.cl/appsenado/index.php?mo=s...            103
# 4581  https://www.senado.cl/appsenado/index.php?mo=s...            103
# 4582  https://www.senado.cl/appsenado/index.php?mo=s...            103
# 4583  https://www.senado.cl/appsenado/index.php?mo=s...            103
#
#      tramite_constitucional  \
# 2066
# 2067
# 2068
# 2069
# 2070
# ...                     ...
# 4579
# 4580
# 4581
# 4582
# 4583
#
#                                                 detalle  sesion_id  ...  \
# 2066  {'NO': [], 'SI': ['Allamand Z., Andrés', 'Alle...       7979  ...
# 2067  {'NO': ['Allamand Z., Andrés', 'Aravena A., Ca...       7981  ...
# 2068  {'NO': [], 'SI': ['Allamand Z., Andrés', 'Alle...       7981  ...
# 2069  {'NO': [], 'SI': ['Allamand Z., Andrés', 'Alle...       7981  ...
# 2070  {'NO': ['Guillier Á., Alejandro', 'Quintana L....       7981  ...
# ...                                                 ...        ...  ...
# 4579  {'NO': ['Coloma C., Juan Antonio', 'Ebensperge...       9625  ...
# 4580  {'NO': [], 'SI': ['Allende B., Isabel', 'Arave...       9627  ...
# 4581  {'NO': [], 'SI': ['Aravena A., Carmen Gloria',...       9627  ...
# 4582  {'NO': [], 'SI': ['Allende B., Isabel', 'Arave...       9627  ...
# 4583  {'NO': ['Kuschel S., Carlos Ignacio'], 'SI': [...       9627  ...
#
#       articulo  camara tipo votos_no                quorum  votos_si  \
# 2066            SENADO             0        Mayoría simple        35
# 2067            SENADO            14        Mayoría simple        10
# 2068            SENADO             0  Cuatro séptimos Q.C.        37
# 2069            SENADO             0  Cuatro séptimos Q.C.        37
# 2070            SENADO             2        Mayoría simple        26
# ...        ...     ...  ...      ...                   ...       ...
# 4579            SENADO             3                  Q.C.        36
# 4580            SENADO             0        Mayoría simple        24
# 4581            SENADO             0        Mayoría simple        32
# 4582            SENADO             0                  Q.C.        37
# 4583            SENADO             1        Mayoría simple        27
#
#                                                 materia  votos_abs  \
# 2066  Perfecciona los beneficios otorgados a bombero...          0
# 2067  Informe de la Comisión Mixta constituida para ...          0
# 2068  Proyecto de ley, en segundo trámite constituci...          0
# 2069  Proyecto de ley, iniciado en Moción del Honora...          0
# 2070  Proyecto de ley, en primer trámite constitucio...          1
# ...                                                 ...        ...
# 4579  Enmiendas por mayorías, entre ellas, normas de...          1
# 4580  \n Proyecto de acuerdo de los Honorables  Sena...          0
# 4581  Proyecto de ley, iniciado en Mensaje de Su Exc...          1
# 4582  Proyecto de ley, en primer trámite constitucio...          0
# 4583  Proyecto de ley, en segundo trámite constituci...          0
#
#                                       tokenized_materia       fecha
# 2066  [perfeccion, benefici, otorg, bomber, accident...  2018-03-13
# 2067  [mixt, constitu, resolv, divergent, suscit, tr...  2018-03-14
# 2068                        [moderniz, legisl, bancari]  2018-03-14
# 2069  [inici, mocion, navarr, pen, radiodifusion, au...  2018-03-14
# 2070  [pen, radiodifusion, autoriz, von, baer, mont,...  2018-03-14
# ...                                                 ...         ...
# 4579                     [enmiend, mayor, norm, quorum]  2024-03-05
# 4580  [nuñez, araven, carvajal, gatic, pascual, prov...  2024-03-06
# 4581  [inici, mensaj, excelent, divers, cuerp, legal...  2024-03-06
# 4582  [divers, cuerp, legal, objet, adopt, med, comb...  2024-03-06
# 4583  [univers, estatal, cre, univers, biobi, autori...  2024-03-06
#
# [2518 rows x 22 columns]

# %%
from collections import Counter

counter = Counter(token for tokens in votaciones_df['tokenized_materia'] for token in tokens)

most_common_materias = counter.most_common(20)
most_common_materias
# Out:
# [('constitu', 291),
#  ('rechaz', 263),
#  ('discusion', 246),
#  ('bien', 227),
#  ('refund', 220),
#  ('present', 211),
#  ('si', 200),
#  ('orden', 196),
#  ('castr', 195),
#  ('enmiend', 181),
#  ('numer', 180),
#  ('servici', 177),
#  ('rincon', 172),
#  ('nuev', 172),
#  ('objet', 165),
#  ('cre', 162),
#  ('chil', 160),
#  ('reform', 160),
#  ('chahuan', 159),
#  ('respect', 155)]
